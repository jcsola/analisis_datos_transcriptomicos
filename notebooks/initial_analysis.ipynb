# %% [markdown]
# # Data Science Jobs Analysis

# %% [markdown]
# By means of the following analysis, the aim is to know the salary of a Data Scientist, depending on different factors, such as the country where he/she works, the experience he/she has, the position in the company, etc.

# %% [markdown]
# The original dataset can be found at the following url: https://www.kaggle.com/datasets/niyalthakkar/data-science-jobs-analysis

# %%
import pandas as pd

# %%
data = pd.read_csv("./../data/ds.salaries.csv")

# %%
data.head(10)
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
# 5           5       2020               EN              FT
# 6           6       2020               SE              FT
# 7           7       2020               MI              FT
# 8           8       2020               MI              FT
# 9           9       2020               SE              FT
#
#                     job_title    salary salary_currency  salary_in_usd  \
# 0              Data Scientist     70000             EUR          79833
# 1  Machine Learning Scientist    260000             USD         260000
# 2           Big Data Engineer     85000             GBP         109024
# ...
